# %% [markdown]
# <a href="https://colab.research.google.com/github/nuhuynhh/NBA-Head-to-Head-Comparison-24-25szn-/blob/main/NBAProject(2_23).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd;
import numpy as np;

file_path = 'database_24_25.csv'
nba_data = pd.read_csv(file_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2062402022.py in <cell line: 0>()
#       3
#       4 file_path = 'database_24_25.csv'
# ----> 5 nba_data = pd.read_csv(file_path)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'database_24_25.csv'

# %%
print("First 5 row of the dataset:")
print(nba_data.head(10));
# Out:
# First 5 row of the dataset:
#           Player   Tm  Opp Res     MP  FG  FGA    FG%  3P  3PA  ...  DRB  TRB  \
# 0   Jayson Tatum  BOS  NYK   W  30.30  14   18  0.778   8   11  ...    4    4
# 1  Anthony Davis  LAL  MIN   W  37.58  11   23  0.478   1    3  ...   13   16
# 2  Derrick White  BOS  NYK   W  26.63   8   13  0.615   6   10  ...    3    3
# 3   Jrue Holiday  BOS  NYK   W  30.52   7    9  0.778   4    6  ...    2    4
# 4  Miles McBride  NYK  BOS   L  25.85   8   10  0.800   4    5  ...    0    0
# 5  Rui Hachimura  LAL  MIN   W  35.08   7   14  0.500   1    4  ...    2    5
# 6   Jaylen Brown  BOS  NYK   W  29.90   7   18  0.389   5    9  ...    5    7
# 7    Rudy Gobert  MIN  LAL   L  35.33   5    8  0.625   0    0  ...   11   14
# 8  Julius Randle  MIN  LAL   L  34.32   5   10  0.500   1    3  ...    6    9
# 9     Al Horford  BOS  NYK   W  26.08   4    7  0.571   3    5  ...    3    3
#
#    AST  STL  BLK  TOV  PF  PTS  GmSc      Data
# 0   10    1    1    1   1   37  38.1  10/22/24
# 1    4    1    3    1   1   36  34.0  10/22/24
# 2    4    1    0    0   1   24  22.4  10/22/24
# 3    4    1    0    0   2   18  19.5  10/22/24
# 4    2    0    0    1   1   22  17.8  10/22/24
# 5    1    2    1    0   2   18  15.9  10/22/24
# 6    1    1    0    1   3   23  15.6  10/22/24
# 7    2    0    1    1   4   13  13.9  10/22/24
# 8    4    0    0    2   3   16  13.7  10/22/24
# 9    5    1    1    0   2   11  13.0  10/22/24
#
# [10 rows x 25 columns]

# %%
#Display info on dataypes
nba_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16508 entries, 0 to 16511
# Data columns (total 25 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  16508 non-null  object
#  1   Tm      16508 non-null  object
#  2   Opp     16508 non-null  object
#  3   Res     16508 non-null  object
#  4   MP      16508 non-null  float64
#  5   FG      16508 non-null  int64
#  6   FGA     16508 non-null  int64
#  7   FG%     16508 non-null  float64
#  8   3P      16508 non-null  int64
#  9   3PA     16508 non-null  int64
#  10  3P%     16508 non-null  float64
#  11  FT      16508 non-null  int64
#  12  FTA     16508 non-null  int64
#  13  FT%     16508 non-null  float64
#  14  ORB     16508 non-null  int64
#  15  DRB     16508 non-null  int64
#  16  TRB     16508 non-null  int64
#  17  AST     16508 non-null  int64
#  18  STL     16508 non-null  int64
#  19  BLK     16508 non-null  int64
#  20  TOV     16508 non-null  int64
#  21  PF      16508 non-null  int64
#  22  PTS     16508 non-null  int64
#  23  GmSc    16508 non-null  float64
#  24  Data    16508 non-null  object
# dtypes: float64(5), int64(15), object(5)
# memory usage: 3.3+ MB

# %%
#find missing values
print('Print Missing Values in Each Column:');
print(nba_data.isnull().sum())
# Out:
# Print Missing Values in Each Column:
# Player    0
# Tm        0
# Opp       0
# Res       0
# MP        0
# FG        0
# FGA       0
# FG%       0
# 3P        0
# 3PA       0
# 3P%       0
# FT        0
# FTA       0
# FT%       0
# ORB       0
# DRB       0
# TRB       0
# AST       0
# STL       0
# BLK       0
# TOV       0
# PF        0
# PTS       0
# GmSc      0
# Data      0
# dtype: int64

# %%
#
print('Display the dataset to Help Detect Errors:')
print(nba_data.describe())
# Out:
# Display the dataset to Help Detect Errors:
#                  MP            FG           FGA           FG%            3P  \
# count  16508.000000  16508.000000  16508.000000  16508.000000  16508.000000
# mean      22.410688      3.849891      8.273746      0.427631      1.250363
# std       10.892382      3.255707      6.070804      0.254882      1.523711
# min        0.020000      0.000000      0.000000      0.000000      0.000000
# 25%       14.430000      1.000000      4.000000      0.286000      0.000000
# 50%       23.430000      3.000000      7.000000      0.444000      1.000000
# 75%       31.330000      6.000000     12.000000      0.571000      2.000000
# max       50.480000     22.000000     38.000000      1.000000     10.000000
#
#                 3PA           3P%            FT           FTA           FT%  \
# count  16508.000000  16508.000000  16508.000000  16508.000000  16508.000000
# mean       3.478798      0.263783      1.573298      2.017386      0.417838
# std        3.151643      0.286277      2.233510      2.689006      0.435775
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.000000      0.000000      0.000000      0.000000      0.000000
# 50%        3.000000      0.250000      1.000000      1.000000      0.333000
# 75%        5.000000      0.500000      2.000000      3.000000      1.000000
# max       20.000000      1.000000     18.000000     26.000000      1.000000
#
#                 ORB           DRB           TRB           AST           STL  \
# count  16508.000000  16508.000000  16508.000000  16508.000000  16508.000000
# mean       1.027502      3.072571      4.100073      2.454446      0.770172
# std        1.371625      2.717434      3.478488      2.613542      0.991086
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      1.000000      2.000000      1.000000      0.000000
# 50%        1.000000      2.000000      3.000000      2.000000      0.000000
# 75%        2.000000      4.000000      6.000000      4.000000      1.000000
# max       12.000000     23.000000     28.000000     22.000000      8.000000
#
#                 BLK           TOV            PF           PTS          GmSc
# count  16508.000000  16508.000000  16508.000000  16508.000000  16508.000000
# mean       0.468197      1.274170      1.749576     10.523443      8.577187
# std        0.833446      1.428854      1.436332      8.829044      7.821385
# min        0.000000      0.000000      0.000000      0.000000     -7.600000
# 25%        0.000000      0.000000      1.000000      3.000000      2.400000
# 50%        0.000000      1.000000      2.000000      9.000000      7.100000
# 75%        1.000000      2.000000      3.000000     16.000000     13.300000
# max       10.000000     11.000000      6.000000     60.000000     54.200000

# %%
#Only include players with minutes played over 0
nba_data = nba_data[nba_data['MP'] > 0]

#Check for missing values after preprocessing
print('Print Missing Values in Each Column:');
print(nba_data.isnull().sum())
# Out:
# Print Missing Values in Each Column:
# Player    0
# Tm        0
# Opp       0
# Res       0
# MP        0
# FG        0
# FGA       0
# FG%       0
# 3P        0
# 3PA       0
# 3P%       0
# FT        0
# FTA       0
# FT%       0
# ORB       0
# DRB       0
# TRB       0
# AST       0
# STL       0
# BLK       0
# TOV       0
# PF        0
# PTS       0
# GmSc      0
# Data      0
# dtype: int64

# %%
#Matplot Installation
import matplotlib.pyplot as plt
import seaborn as sns

#Set up plot environment
sns.set_style = ("blackgrid")

#
sns.histplot(data=nba_data, x="MP", col="PTS", kde=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 9
#       6 sns.set_style = ("blackgrid")
#       8 #
# ----> 9 sns.histplot(data=nba_data, x="MP", col="PTS", kde=True)
#      10 plt.show()
#
# File /opt/anaconda3/lib/python3.13/site-packages/seaborn/distributions.py:1396, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1394     else:
#    1395         method = ax.plot
# -> 1396     color = _default_color(method, hue, color, kwargs)
#    1398 if not p.has_xy_data:
#    1399     return ax
#
# File /opt/anaconda3/lib/python3.13/site-packages/seaborn/utils.py:127, in _default_color(method, hue, color, kws, saturation)
#     122     scout.remove()
#     124 elif method.__name__ == "bar":
#     125
#     126     # bar() needs masked, not empty data, to generate a patch
# --> 127     scout, = method([np.nan], [np.nan], **kws)
#     128     color = to_rgb(scout.get_facecolor())
#     129     scout.remove()
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/axes/_axes.py:2654, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2645 for l, b, w, h, c, e, lw, htch, lbl in args:
#    2646     r = mpatches.Rectangle(
#    2647         xy=(l, b), width=w, height=h,
#    2648         facecolor=c,
#    (...)   2652         hatch=htch,
#    2653         )
# -> 2654     r._internal_update(kwargs)
#    2655     r.get_path()._interpolation_steps = 100
#    2656     if orientation == 'vertical':
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/artist.py:1233, in Artist._internal_update(self, kwargs)
#    1226 def _internal_update(self, kwargs):
#    1227     """
#    1228     Update artist properties without prenormalizing them, but generating
#    1229     errors as if calling `set`.
#    1230
#    1231     The lack of prenormalization is to maintain backcompatibility.
#    1232     """
# -> 1233     return self._update_props(
#    1234         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1235         "{prop_name!r}")
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/artist.py:1206, in Artist._update_props(self, props, errfmt)
#    1204             func = getattr(self, f"set_{k}", None)
#    1205             if not callable(func):
# -> 1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
#    1209             ret.append(func(v))
#    1210 if ret:
#
# AttributeError: Rectangle.set() got an unexpected keyword argument 'col'
